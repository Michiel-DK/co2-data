# %%
import os
import pandas as pd
import numpy as np

# %%
table = pd.read_csv('owid-co2-data.csv')

# %%
table
# Out:
#       iso_code      country  year     co2  co2_growth_prct  co2_growth_abs  \
# 0          AFG  Afghanistan  1949   0.015              NaN             NaN
# 1          AFG  Afghanistan  1950   0.084          475.000           0.070
# 2          AFG  Afghanistan  1951   0.092            8.696           0.007
# 3          AFG  Afghanistan  1952   0.092              NaN             NaN
# 4          AFG  Afghanistan  1953   0.106           16.000           0.015
# ...        ...          ...   ...     ...              ...             ...
# 23703      ZWE     Zimbabwe  2015  12.170            1.653           0.198
# 23704      ZWE     Zimbabwe  2016  10.815          -11.139          -1.356
# 23705      ZWE     Zimbabwe  2017  10.247           -5.251          -0.568
# 23706      ZWE     Zimbabwe  2018  11.341           10.674           1.094
# 23707      ZWE     Zimbabwe  2019  10.374           -8.521          -0.966
#
# ...

# %%
pwd
# Out:
# '/Users/admin/code/Michiel-DK/co2-data/co2-data'

# %%
continents = pd.read_csv('scripts/input/shared/continents.csv')

# %%
continents.groupby('Region').agg('count')
# Out:
#                             Country  Code  Year
# Region
# Africa                           61    61    61
# Antarctica                        4     4     4
# Asia                             62    62    62
# Asia (excl. China & India)       60     0    60
# EU-27                            27     0    27
# EU-28                            28     0    28
# Europe                           75    75    75
# Europe (excl. EU-27)             43     0    43
# Europe (excl. EU-28)             44     0    44
# North America                    42    42    42
# North America (excl. USA)        41     0    41
# Oceania                          26    26    26
# South America                    15    15    15

# %%
def get_continents(dataframe):
    continents = pd.read_csv(
        os.path.join(INPUT_DIR, "shared/continents.csv"),
        usecols=["Country", "Region"]
    )
    continents = continents.merge(dataframe, on="Country")
    continents = (
        continents
        .groupby(["Region", "Year"], as_index=False)
        .sum()
        .rename(columns={"Region": "Country"})
        .replace(0, pd.NA)
    )
    return continents

# %%
continents.drop_duplicates(inplace=True)

# %%
continents = continents[['Country','Region']]

# %%
continents.rename(columns={'Country':'country','Region':'region'},inplace=True)
# Out:
# /Users/admin/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/pandas/core/frame.py:4446: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
table.merge(continents, on='country')
# Out:
#       iso_code      country  year     co2  co2_growth_prct  co2_growth_abs  \
# 0          AFG  Afghanistan  1949   0.015              NaN             NaN
# 1          AFG  Afghanistan  1949   0.015              NaN             NaN
# 2          AFG  Afghanistan  1950   0.084          475.000           0.070
# 3          AFG  Afghanistan  1950   0.084          475.000           0.070
# 4          AFG  Afghanistan  1951   0.092            8.696           0.007
# ...        ...          ...   ...     ...              ...             ...
# 41673      ZWE     Zimbabwe  2015  12.170            1.653           0.198
# 41674      ZWE     Zimbabwe  2016  10.815          -11.139          -1.356
# 41675      ZWE     Zimbabwe  2017  10.247           -5.251          -0.568
# 41676      ZWE     Zimbabwe  2018  11.341           10.674           1.094
# 41677      ZWE     Zimbabwe  2019  10.374           -8.521          -0.966
#
# ...

# %%
codebook = pd.read_csv('owid-co2-codebook.csv')

# %%
plt.plot(table.groupby('year').agg({'co2':'sum'}))

# %%
table.merge(continents)
